# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import *

# %%
data1 = pd.read_excel('KPMG_task1.xlsx', sheet_name='Transactions', index_col=None)
data1=pd.DataFrame(data1)
data1.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
data1.shape
# Out:
# (20000, 13)

# %%
data2 = pd.read_excel('KPMG_task1.xlsx', sheet_name='CustomerAddress', index_col=None)
data2=pd.DataFrame(data2)
data2.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
data3 = pd.merge(left=data1, right=data2, left_on = 'customer_id', right_on = 'customer_id')

# %%
data3.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost  product_first_sold_date            address  \
# ...

# %%
data3.shape
# Out:
# (19968, 18)

# %%
data4 = pd.read_excel('KPMG_task1.xlsx', sheet_name='CustomerDemographic', index_col=None)
data4 = pd.DataFrame(data4)
data4.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
data4.shape
# Out:
# (4000, 13)

# %%
data = pd.merge(left=data3, right=data4, left_on = 'customer_id', right_on = 'customer_id')

# %%
data.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    gender  past_3_years_bike_related_purchases        DOB  \
# ...

# %%
data.shape
# Out:
# (19968, 30)

# %%
data.tail(10)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 19958           17796           6         2236       2017-11-11           0.0
# 19959           17451          48         2115       2017-08-14           1.0
# 19960           19740          45         2115       2017-11-13           0.0
# 19961           17596          10         1569       2017-11-07           1.0
# 19962           17669           8          130       2017-10-15           0.0
# 19963           19854          68          130       2017-02-02           1.0
# 19964           17966          17         2789       2017-12-06           0.0
# 19965           18462          80         2789       2017-06-20           0.0
# 19966           17981          69         3446       2017-12-26           1.0
# 19967           18165          86         3446       2017-12-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# ...

# %%
data.columns.unique()
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
data[data['gender']=='U']
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 123                17          79         2426       2017-04-03           0.0
# 124               302          42         2426       2017-03-17           1.0
# 125              1038          88         2426       2017-08-31           1.0
# 126              4030          71         2426       2017-08-23           0.0
# 127             10524          26         2426       2017-12-14           1.0
# 373                60          60         3473       2017-12-18           0.0
# 374             11079           1         3473       2017-08-04           0.0
# 375             16206          33         3473       2017-10-07           1.0
# 376             17845          53         3473       2017-05-19           0.0
# 400                64           0         2000       2017-07-08           0.0
# 401              3931          56         2000       2017-08-16           1.0
# ...

# %%
data
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# 5                9155          91         3120       2017-10-30           1.0
# 6               11409          95         3120       2017-01-30           0.0
# 7               13066          38         3120       2017-01-20           1.0
# 8               15829          41         3120       2017-12-10           0.0
# 9               18612          10         3120       2017-10-24           0.0
# 10                  3          37          402       2017-10-16           0.0
# ...

# %%
#data_final.shape

# %%
#data_final.dtypes
data['DOB'] = data['DOB'].dt.strftime('%Y/%m/%d')

# %%
data[['Year','Month','Day']]=data.DOB.str.split('/', expand=True)
data.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
data[data['Year']=='1843'][['first_name','last_name']]
# Out:
#      first_name last_name
# 5894   Jephthah  Bachmann
# 5895   Jephthah  Bachmann
# 5896   Jephthah  Bachmann
# 5897   Jephthah  Bachmann
# 5898   Jephthah  Bachmann
# 5899   Jephthah  Bachmann
# 5900   Jephthah  Bachmann
# 5901   Jephthah  Bachmann
# 5902   Jephthah  Bachmann

# %%
data_final = data.drop(['product_id', 'transaction_date', 'product_first_sold_date', 'address', 'postcode', 'country', 'first_name',
           'last_name', 'job_title', 'deceased_indicator', 'default'], axis=1)

# %%
data_final.head()
# Out:
#    transaction_id  customer_id  online_order order_status           brand  \
# 0               1         2950           0.0     Approved           Solex
# 1           11065         2950           0.0     Approved  Giant Bicycles
# 2           18923         2950           0.0     Approved           Solex
# 3               2         3120           1.0     Approved   Trek Bicycles
# 4            6862         3120           0.0     Approved  Giant Bicycles
#
#   product_line product_class product_size  list_price  standard_cost  ...  \
# 0     Standard        medium       medium       71.49          53.62  ...
# 1     Standard        medium       medium     1403.50         954.82  ...
# 2     Standard        medium       medium      478.16         298.72  ...
# 3     Standard        medium        large     2091.47         388.92  ...
# 4     Standard          high       medium     1129.13         677.48  ...
#
#    gender  past_3_years_bike_related_purchases         DOB  \
# ...

# %%
data_filt = data_final[data_final['DOB']!= 'NaT']
data_filt.head()
# Out:
#    transaction_id  customer_id  online_order order_status           brand  \
# 0               1         2950           0.0     Approved           Solex
# 1           11065         2950           0.0     Approved  Giant Bicycles
# 2           18923         2950           0.0     Approved           Solex
# 3               2         3120           1.0     Approved   Trek Bicycles
# 4            6862         3120           0.0     Approved  Giant Bicycles
#
#   product_line product_class product_size  list_price  standard_cost  ...  \
# 0     Standard        medium       medium       71.49          53.62  ...
# 1     Standard        medium       medium     1403.50         954.82  ...
# 2     Standard        medium       medium      478.16         298.72  ...
# 3     Standard        medium        large     2091.47         388.92  ...
# 4     Standard          high       medium     1129.13         677.48  ...
#
#    gender  past_3_years_bike_related_purchases         DOB  \
# ...

# %%
data_filt['Year'] = data_filt['Year'].astype(int)
# Out:
# C:\Users\radhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_filt.dtypes
# Out:
# transaction_id                           int64
# customer_id                              int64
# online_order                           float64
# order_status                            object
# brand                                   object
# product_line                            object
# product_class                           object
# product_size                            object
# list_price                             float64
# standard_cost                          float64
# state                                   object
# property_valuation                       int64
# gender                                  object
# past_3_years_bike_related_purchases      int64
# DOB                                     object
# job_industry_category                   object
# wealth_segment                          object
# owns_car                                object
# tenure                                 float64
# Year                                     int32
# ...

# %%
data_filt['age'] = 2017-data_filt['Year']
# Out:
# C:\Users\radhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#data_filt.head()
data_filt['profit']=data_filt['list_price']-data_filt['standard_cost']
# Out:
# C:\Users\radhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = data_filt.drop(['transaction_id', 'list_price', 'standard_cost', 'DOB', 'Year', 'Month', 'Day'], axis=1)
df.head()
# Out:
#    customer_id  online_order order_status           brand product_line  \
# 0         2950           0.0     Approved           Solex     Standard
# 1         2950           0.0     Approved  Giant Bicycles     Standard
# 2         2950           0.0     Approved           Solex     Standard
# 3         3120           1.0     Approved   Trek Bicycles     Standard
# 4         3120           0.0     Approved  Giant Bicycles     Standard
#
#   product_class product_size state  property_valuation  gender  \
# 0        medium       medium   VIC                   6    Male
# 1        medium       medium   VIC                   6    Male
# 2        medium       medium   VIC                   6    Male
# 3        medium        large   NSW                   5  Female
# 4          high       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases job_industry_category wealth_segment  \
# 0                                   19    Financial Services  Mass Customer
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                               0
# online_order                            351
# order_status                              0
# brand                                   187
# product_line                            187
# product_class                           187
# product_size                            187
# state                                     0
# property_valuation                        0
# gender                                    0
# past_3_years_bike_related_purchases       0
# job_industry_category                  3222
# wealth_segment                            0
# owns_car                                  0
# tenure                                    0
# age                                       0
# profit                                  187
# dtype: int64

# %%
df.shape
# Out:
# (19522, 17)

# %%
df=df.dropna(subset=['brand'])

# %%
df.isnull().sum()
# Out:
# customer_id                               0
# online_order                            349
# order_status                              0
# brand                                     0
# product_line                              0
# product_class                             0
# product_size                              0
# state                                     0
# property_valuation                        0
# gender                                    0
# past_3_years_bike_related_purchases       0
# job_industry_category                  3192
# wealth_segment                            0
# owns_car                                  0
# tenure                                    0
# age                                       0
# profit                                    0
# dtype: int64

# %%
df.drop(['online_order', 'job_industry_category'], axis=1,inplace=True)

# %%
df['state'].unique()
# Out:
# array(['VIC', 'NSW', 'QLD', 'Victoria', 'New South Wales'], dtype=object)

# %%
df['state'].replace(['New South Wales','Victoria'],['NSW','VIC'],inplace=True)

# %%
df.head()
# Out:
#    customer_id order_status           brand product_line product_class  \
# 0         2950     Approved           Solex     Standard        medium
# 1         2950     Approved  Giant Bicycles     Standard        medium
# 2         2950     Approved           Solex     Standard        medium
# 3         3120     Approved   Trek Bicycles     Standard        medium
# 4         3120     Approved  Giant Bicycles     Standard          high
#
#   product_size state  property_valuation  gender  \
# 0       medium   VIC                   6    Male
# 1       medium   VIC                   6    Male
# 2       medium   VIC                   6    Male
# 3        large   NSW                   5  Female
# 4       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  age  \
# 0                                   19  Mass Customer      Yes    10.0   62
# 1                                   19  Mass Customer      Yes    10.0   62
# ...

# %%
df['state'].unique()
# Out:
# array(['VIC', 'NSW', 'QLD'], dtype=object)

# %%
df['age'].min()
# Out:
# 15

# %%
df['age'].max()
# Out:
# 174

# %%
df['age'].replace([174],[74],inplace=True)

# %%
df['age'].max()
# Out:
# 86

# %%
df[df['gender']=='U']
# Out:
#       customer_id order_status           brand product_line product_class  \
# 5894           34     Approved           Solex         Road        medium
# 5895           34     Approved  Norco Bicycles     Standard           low
# 5896           34     Approved           Solex      Touring        medium
# 5897           34     Approved        WeareA2B     Standard        medium
# 5898           34     Approved  Giant Bicycles     Standard          high
# 5899           34     Approved           Solex     Standard        medium
# 5901           34     Approved        WeareA2B         Road           low
# 5902           34     Approved        WeareA2B     Standard        medium
#
#      product_size state  property_valuation gender  \
# 5894        small   QLD                   8      U
# 5895       medium   QLD                   8      U
# 5896        large   QLD                   8      U
# 5897       medium   QLD                   8      U
# ...

# %%
df['gender'].replace(['U'],['Female'],inplace=True)
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'F', 'M', 'Femal'], dtype=object)

# %%
df['gender'].replace(['M','F','Femal'],['Male','Female','Female'],inplace=True)

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.head()
# Out:
#    customer_id order_status           brand product_line product_class  \
# 0         2950     Approved           Solex     Standard        medium
# 1         2950     Approved  Giant Bicycles     Standard        medium
# 2         2950     Approved           Solex     Standard        medium
# 3         3120     Approved   Trek Bicycles     Standard        medium
# 4         3120     Approved  Giant Bicycles     Standard          high
#
#   product_size state  property_valuation  gender  \
# 0       medium   VIC                   6    Male
# 1       medium   VIC                   6    Male
# 2       medium   VIC                   6    Male
# 3        large   NSW                   5  Female
# 4       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  age  \
# 0                                   19  Mass Customer      Yes    10.0   62
# 1                                   19  Mass Customer      Yes    10.0   62
# ...

# %%
df.shape
# Out:
# (19335, 15)

# %%
for i in range(len(df)):
    if df.iloc[[i],[13]]<30 and df.iloc[[i],[13]]>=15:
        df.loc[['age_group']]=='15-30'
    elif df.iloc[[i],[13]]<45 and df.iloc[[i],[13]]>=30:
        df.loc[['age_group']]=='30-45'
    elif df.iloc[[i],[13]]<60 and df.iloc[[i],[13]]>=45:
        df.loc[['age_group']]=='45-60'
    elif df.iloc[[i],[13]]<75 and df.iloc[[i],[13]]>=60:
        df.loc[['age_group']]=='60-75'
    else:
        df.loc[['age_group']]=='75-90'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-852ddd9de75d> in <module>
#       1 for i in range(len(df)):
# ----> 2     if df.iloc[[i],[13]]<30 and df.iloc[[i],[13]]>=15:
#       3         df.loc[['age_group']]=='15-30'
#       4     elif df.iloc[[i],[13]]<45 and df.iloc[[i],[13]]>=30:
#       5         df.loc[['age_group']]=='30-45'
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['age_group']=pd.cut(df['age'], bins=[15,30,45,60,75,90], labels=['15-30','30-45','45-60','60-75','75-90'])

# %%
df.head()
# Out:
#    customer_id order_status           brand product_line product_class  \
# 0         2950     Approved           Solex     Standard        medium
# 1         2950     Approved  Giant Bicycles     Standard        medium
# 2         2950     Approved           Solex     Standard        medium
# 3         3120     Approved   Trek Bicycles     Standard        medium
# 4         3120     Approved  Giant Bicycles     Standard          high
#
#   product_size state  property_valuation  gender  \
# 0       medium   VIC                   6    Male
# 1       medium   VIC                   6    Male
# 2       medium   VIC                   6    Male
# 3        large   NSW                   5  Female
# 4       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  age  \
# 0                                   19  Mass Customer      Yes    10.0   62
# 1                                   19  Mass Customer      Yes    10.0   62
# ...

# %%
df['profit'].max()
# Out:
# 1702.5499999999997

# %%
df['profit'].min()
# Out:
# 4.8

# %%
df.drop('age', axis=1, inplace=True)

# %%
df.head()
# Out:
#    customer_id order_status           brand product_line product_class  \
# 0         2950     Approved           Solex     Standard        medium
# 1         2950     Approved  Giant Bicycles     Standard        medium
# 2         2950     Approved           Solex     Standard        medium
# 3         3120     Approved   Trek Bicycles     Standard        medium
# 4         3120     Approved  Giant Bicycles     Standard          high
#
#   product_size state  property_valuation  gender  \
# 0       medium   VIC                   6    Male
# 1       medium   VIC                   6    Male
# 2       medium   VIC                   6    Male
# 3        large   NSW                   5  Female
# 4       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  \
# 0                                   19  Mass Customer      Yes    10.0
# 1                                   19  Mass Customer      Yes    10.0
# ...

# %%
df['order_status'].replace(['Approved', 'Cancelled'], [1,0], inplace=True)

# %%
df_new=pd.get_dummies(df, columns=['brand', 'product_line', 'product_class', 'product_size', 'state', 
                            'gender', 'wealth_segment', 'owns_car', 'age_group'], drop_first=True)

# %%
df_new['order_status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_new.head()
# Out:
#    customer_id  order_status  property_valuation  \
# 0         2950             1                   6
# 1         2950             1                   6
# 2         2950             1                   6
# 3         3120             1                   5
# 4         3120             1                   5
#
#    past_3_years_bike_related_purchases  tenure   profit  brand_Norco Bicycles  \
# 0                                   19    10.0    17.87                     0
# 1                                   19    10.0   448.68                     0
# 2                                   19    10.0   179.44                     0
# 3                                   89    10.0  1702.55                     0
# 4                                   89    10.0   451.65                     0
#
#    brand_OHM Cycles  brand_Solex  brand_Trek Bicycles  ...  state_QLD  \
# 0                 0            1                    0  ...          0
# ...

# %%
df_new.drop('customer_id', axis=1, inplace=True)

# %%
df_new.head()
# Out:
#    order_status  property_valuation  past_3_years_bike_related_purchases  \
# 0             1                   6                                   19
# 1             1                   6                                   19
# 2             1                   6                                   19
# 3             1                   5                                   89
# 4             1                   5                                   89
#
#    tenure   profit  brand_Norco Bicycles  brand_OHM Cycles  brand_Solex  \
# 0    10.0    17.87                     0                 0            1
# 1    10.0   448.68                     0                 0            0
# 2    10.0   179.44                     0                 0            1
# 3    10.0  1702.55                     0                 0            0
# 4    10.0   451.65                     0                 0            0
#
#    brand_Trek Bicycles  brand_WeareA2B  ...  state_QLD  state_VIC  \
# ...

# %%
corr = df_new.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col1 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col5 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_e4bc218c_2ac0_11eb_9df7_3c2c30d4e0b1row0_col6 {
#             background-color:  #7597f6;
#             color:  #000000;
# ...

# %%
# Time for some visualizations LOL
# I am going to consider 'Approved' as a successful sale and 'Cancelled' as no sale
# LET'S GET IT!!

d1 = df.groupby('brand').count()

# %%
d1.head()
# Out:
#                 customer_id  order_status  product_line  product_class  \
# brand
# Giant Bicycles         3237          3237          3237           3237
# Norco Bicycles         2828          2828          2828           2828
# OHM Cycles             2976          2976          2976           2976
# Solex                  4174          4174          4174           4174
# Trek Bicycles          2914          2914          2914           2914
#
#                 product_size  state  property_valuation  gender  \
# brand
# Giant Bicycles          3237   3237                3237    3237
# Norco Bicycles          2828   2828                2828    2828
# OHM Cycles              2976   2976                2976    2976
# Solex                   4174   4174                4174    4174
# Trek Bicycles           2914   2914                2914    2914
#
#                 past_3_years_bike_related_purchases  wealth_segment  owns_car  \
# brand
# ...

# %%
# Plot for sales by brand
plt.figure(figsize=(9,5))
plt.bar(x=d1.index, height=d1['customer_id'])
plt.title('Customer transactions - By product brand')
plt.xlabel('Product brand', fontsize=12)
plt.ylabel('Number of transactions (App. & Can.)', fontsize=12)
plt.show()

# %%
# Plot for sales by state
d2 = df.groupby('state').count()
plt.figure(figsize=(9,5))
plt.bar(x=d2.index, height=d2['customer_id'])
plt.title('Customer transactions - By state')
plt.xlabel('State', fontsize=12)
plt.ylabel('Number of transactions (App. & Can.)', fontsize=12)
plt.show()

# %%
# Transactions by age group
d3 = df.groupby('age_group').count()
plt.figure(figsize=(9,5))
plt.bar(x=d3.index, height=d3['customer_id'])
plt.title('Customer transactions - By age group')
plt.xlabel('Age group', fontsize=12)
plt.ylabel('Number of transactions (App. & Can.)', fontsize=12)
plt.show()

# %%
# Transactions by gender
d4 = df.groupby('gender').count()
plt.figure(figsize=(9,5))
plt.bar(x=d4.index, height=d4['customer_id'])
plt.title('Customer transactions - By gender')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Number of transactions (App. & Can.)', fontsize=12)
plt.show()

# %%
df['profit_group']=pd.cut(df['profit'], bins=[0,300,600,900,1200,1500,1800],
                          labels=['0-300','300-600','600-900','900-1200','1200-1500','1500-1800'])
d5 = df.groupby('profit_group').count()
plt.figure(figsize=(15,6))
plt.bar(d5.index, d5['customer_id'])
plt.title('Customer transactions - By profit group')
plt.xlabel('Profit group', fontsize=12)
plt.ylabel('Number of transactions (App. & Can.)', fontsize=12)
plt.show()

# %%
df.head()
# Out:
#    customer_id  order_status           brand product_line product_class  \
# 0         2950             1           Solex     Standard        medium
# 1         2950             1  Giant Bicycles     Standard        medium
# 2         2950             1           Solex     Standard        medium
# 3         3120             1   Trek Bicycles     Standard        medium
# 4         3120             1  Giant Bicycles     Standard          high
#
#   product_size state  property_valuation  gender  \
# 0       medium   VIC                   6    Male
# 1       medium   VIC                   6    Male
# 2       medium   VIC                   6    Male
# 3        large   NSW                   5  Female
# 4       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  \
# 0                                   19  Mass Customer      Yes    10.0
# 1                                   19  Mass Customer      Yes    10.0
# ...

# %%
df_nsw = df[df['state']=='NSW']
df_nsw.head()
# Out:
#    customer_id  order_status           brand product_line product_class  \
# 3         3120             1   Trek Bicycles     Standard        medium
# 4         3120             1  Giant Bicycles     Standard          high
# 5         3120             1           Solex     Standard        medium
# 6         3120             1  Giant Bicycles     Standard        medium
# 7         3120             1           Solex     Standard        medium
#
#   product_size state  property_valuation  gender  \
# 3        large   NSW                   5  Female
# 4       medium   NSW                   5  Female
# 5       medium   NSW                   5  Female
# 6        large   NSW                   5  Female
# 7       medium   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  \
# 3                                   89  Mass Customer      Yes    10.0
# 4                                   89  Mass Customer      Yes    10.0
# ...

# %%
nsw=df_nsw.groupby('brand').count()
plt.figure(figsize=[9,5])
plt.bar(x=nsw.index, height=nsw['customer_id'])
plt.show()

# %%
df_vic = df[df['state']=='VIC']
vic=df_vic.groupby('brand').count()
plt.figure(figsize=[9,5])
plt.bar(x=vic.index, height=vic['customer_id'])
plt.show()

# %%
df_qld = df[df['state']=='QLD']
qld=df_qld.groupby('brand').count()
plt.figure(figsize=[9,5])
plt.bar(x=qld.index, height=qld['customer_id'])
plt.show()

# %%
wealth_seg = df.groupby('wealth_segment').count()
plt.bar(x=wealth_seg.index, height=wealth_seg['customer_id'])
plt.show()

# %%
transaction = df.groupby('customer_id').count()
transaction.head()
# Out:
#              order_status  brand  product_line  product_class  product_size  \
# customer_id
# 1                      11     11            11             11            11
# 2                       3      3             3              3             3
# 4                       2      2             2              2             2
# 5                       6      6             6              6             6
# 6                       5      5             5              5             5
#
#              state  property_valuation  gender  \
# customer_id
# 1               11                  11      11
# 2                3                   3       3
# 4                2                   2       2
# 5                6                   6       6
# 6                5                   5       5
#
#              past_3_years_bike_related_purchases  wealth_segment  owns_car  \
# customer_id
# 1                                             11              11        11
# ...

# %%
d6 = pd.merge(left=df, right=transaction, left_on = 'customer_id', right_on = 'customer_id')

# %%
d6.head()
# Out:
#    customer_id  order_status_x         brand_x product_line_x product_class_x  \
# 0         2950               1           Solex       Standard          medium
# 1         2950               1  Giant Bicycles       Standard          medium
# 2         2950               1           Solex       Standard          medium
# 3         3120               1   Trek Bicycles       Standard          medium
# 4         3120               1  Giant Bicycles       Standard            high
#
#   product_size_x state_x  property_valuation_x gender_x  \
# 0         medium     VIC                     6     Male
# 1         medium     VIC                     6     Male
# 2         medium     VIC                     6     Male
# 3          large     NSW                     5   Female
# 4         medium     NSW                     5   Female
#
#    past_3_years_bike_related_purchases_x  ... state_y property_valuation_y  \
# 0                                     19  ...       3                    3
# ...

# %%
plt.scatter(d6['past_3_years_bike_related_purchases_x'], d6['property_valuation_y'])
plt.show()

# %%
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
Y = df_new['order_status']
X = df_new.drop(['order_status'],axis=1)
model = sm.Logit(Y, sm.add_constant(X))
result = model.fit()
result.summary()
# Out:
# C:\Users\radhi\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...
#          Current function value: 0.050873
#          Iterations: 35
# C:\Users\radhi\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           order_status   No. Observations:                19335
# Model:                          Logit   Df Residuals:                    19308
# Method:                           MLE   Df Model:                           26
# Date:                Thu, 19 Nov 2020   Pseudo R-squ.:                 0.01397
# ...

# %%
df_new.drop('age_group_75-90', axis=1, inplace=True)

# %%
df_new.head()
# Out:
#    order_status  property_valuation  past_3_years_bike_related_purchases  \
# 0             1                   6                                   19
# 1             1                   6                                   19
# 2             1                   6                                   19
# 3             1                   5                                   89
# 4             1                   5                                   89
#
#    tenure   profit  brand_Norco Bicycles  brand_OHM Cycles  brand_Solex  \
# 0    10.0    17.87                     0                 0            1
# 1    10.0   448.68                     0                 0            0
# 2    10.0   179.44                     0                 0            1
# 3    10.0  1702.55                     0                 0            0
# 4    10.0   451.65                     0                 0            0
#
#    brand_Trek Bicycles  brand_WeareA2B  ...  product_size_small  state_QLD  \
# ...

# %%
Y = df_new['order_status']
X = df_new.drop(['order_status'],axis=1)
model = sm.Logit(Y, sm.add_constant(X))
result = model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.050879
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           order_status   No. Observations:                19335
# Model:                          Logit   Df Residuals:                    19309
# Method:                           MLE   Df Model:                           25
# Date:                Thu, 19 Nov 2020   Pseudo R-squ.:                 0.01384
# Time:                        17:43:06   Log-Likelihood:                -983.75
# converged:                       True   LL-Null:                       -997.56
# Covariance Type:            nonrobust   LLR p-value:                    0.3258
# ...
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
df.to_csv("cleaned_for_analysis.csv")

# %%
d_class = df.groupby('product_class').count()

# %%
d_class.head()
# Out:
#                customer_id  order_status  brand  product_line  product_size  \
# product_class
# high                  2946          2946   2946          2946          2946
# low                   2907          2907   2907          2907          2907
# medium               13482         13482  13482         13482         13482
#
#                state  property_valuation  gender  \
# product_class
# high            2946                2946    2946
# low             2907                2907    2907
# medium         13482               13482   13482
#
#                past_3_years_bike_related_purchases  wealth_segment  owns_car  \
# product_class
# high                                          2946            2946      2946
# low                                           2907            2907      2907
# medium                                       13482           13482     13482
#
#                tenure  profit  age_group  profit_group
# product_class
# ...

# %%
plt.figure(figsize=[9,5])
plt.bar(x=d_class.index, height=d_class['customer_id'])
plt.show()

# %%
data_test = pd.read_excel('KPMG_task1.xlsx', sheet_name='NewCustomerList', index_col=None)
data_test=pd.DataFrame(data_test)
data_test.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
data_test['DOB'] = data_test['DOB'].dt.strftime('%Y/%m/%d')

# %%
data_test[['Year','Month','Day']]=data_test.DOB.str.split('/', expand=True)
data_test.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957/07/12             General Manager         Manufacturing
# 1  1970/03/22         Structural Engineer              Property
# 2  1974/08/28      Senior Cost Accountant    Financial Services
# 3  1979/01/28  Account Representative III         Manufacturing
# 4  1965/09/21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  Unnamed: 16  \
# 0      Mass Customer                  N      Yes  ...         0.97
# ...

# %%
data_filt_test = data_test[data_test['DOB']!= 'NaT']
data_filt_test.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957/07/12             General Manager         Manufacturing
# 1  1970/03/22         Structural Engineer              Property
# 2  1974/08/28      Senior Cost Accountant    Financial Services
# 3  1979/01/28  Account Representative III         Manufacturing
# 4  1965/09/21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  Unnamed: 16  \
# 0      Mass Customer                  N      Yes  ...         0.97
# ...

# %%
data_filt_test['age'] = 2017-data_filt_test['Year'].astype(int)
data_filt_test.head()
# Out:
# C:\Users\radhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957/07/12             General Manager         Manufacturing
# ...

# %%
data_filt_test['age_group']=pd.cut(data_filt_test['age'], bins=[15,30,45,60,75,90], labels=['15-30','30-45','45-60','60-75','75-90'])
# Out:
# C:\Users\radhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_filt_test.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957/07/12             General Manager         Manufacturing
# 1  1970/03/22         Structural Engineer              Property
# 2  1974/08/28      Senior Cost Accountant    Financial Services
# 3  1979/01/28  Account Representative III         Manufacturing
# 4  1965/09/21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  Unnamed: 18  \
# 0      Mass Customer                  N      Yes  ...     1.515625
# ...

# %%
test_temp = data_filt_test.drop(['first_name', 'last_name', 'DOB', 'job_title', 'job_industry_category', 'deceased_indicator', 'Unnamed: 18',
           'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value', 'Year', 'Month', 'Day', 'age'], axis=1)

# %%
test_temp.head()
# Out:
#    gender  past_3_years_bike_related_purchases     wealth_segment owns_car  \
# 0    Male                                   86      Mass Customer      Yes
# 1    Male                                   69      Mass Customer       No
# 2  Female                                   10  Affluent Customer       No
# 3  Female                                   64  Affluent Customer      Yes
# 4  Female                                   34  Affluent Customer       No
#
#    tenure              address  postcode state    country  property_valuation  \
# 0      14     45 Shopko Center      4500   QLD  Australia                   6
# 1      16    14 Mccormick Park      2113   NSW  Australia                  11
# 2      10  5 Colorado Crossing      3505   VIC  Australia                   5
# 3       5   207 Annamark Plaza      4814   QLD  Australia                   1
# 4      19    115 Montana Place      2093   NSW  Australia                   9
#
#    Unnamed: 16  Unnamed: 17 age_group
# ...

# %%
test_temp = test_temp.drop(['Unnamed: 16', 'Unnamed: 17', 'address', 'postcode'], axis=1)

# %%
test_temp.head()
# Out:
#    gender  past_3_years_bike_related_purchases     wealth_segment owns_car  \
# 0    Male                                   86      Mass Customer      Yes
# 1    Male                                   69      Mass Customer       No
# 2  Female                                   10  Affluent Customer       No
# 3  Female                                   64  Affluent Customer      Yes
# 4  Female                                   34  Affluent Customer       No
#
#    tenure state    country  property_valuation age_group
# 0      14   QLD  Australia                   6     45-60
# 1      16   NSW  Australia                  11     45-60
# 2      10   VIC  Australia                   5     30-45
# 3       5   QLD  Australia                   1     30-45
# 4      19   NSW  Australia                   9     45-60

# %%
test_temp = test_temp.drop(['country'], axis=1)
test_new=pd.get_dummies(test_temp, columns=['gender', 'wealth_segment', 'owns_car', 'state', 'age_group'], drop_first=True)

# %%
test_new.head()
# Out:
#    past_3_years_bike_related_purchases  tenure  property_valuation  \
# 0                                   86      14                   6
# 1                                   69      16                  11
# 2                                   10      10                   5
# 3                                   64       5                   1
# 4                                   34      19                   9
#
#    gender_Male  wealth_segment_High Net Worth  wealth_segment_Mass Customer  \
# 0            1                              0                             1
# 1            1                              0                             1
# 2            0                              0                             0
# 3            0                              0                             0
# 4            0                              0                             0
#
#    owns_car_Yes  state_QLD  state_VIC  age_group_30-45  age_group_45-60  \
# ...

# %%
df_df = df.drop(['profit', 'brand', 'product_line', 'product_class', 'product_size', 'customer_id'], axis=1)

# %%
df_df.head()
# Out:
#    order_status state  property_valuation  gender  \
# 0             1   VIC                   6    Male
# 1             1   VIC                   6    Male
# 2             1   VIC                   6    Male
# 3             1   NSW                   5  Female
# 4             1   NSW                   5  Female
#
#    past_3_years_bike_related_purchases wealth_segment owns_car  tenure  \
# 0                                   19  Mass Customer      Yes    10.0
# 1                                   19  Mass Customer      Yes    10.0
# 2                                   19  Mass Customer      Yes    10.0
# 3                                   89  Mass Customer      Yes    10.0
# 4                                   89  Mass Customer      Yes    10.0
#
#   age_group profit_group
# 0     60-75        0-300
# 1     60-75      300-600
# 2     60-75        0-300
# 3     30-45    1500-1800
# 4     30-45      300-600

# %%
df_dummies=pd.get_dummies(df_df, columns=['gender', 'wealth_segment', 'owns_car', 'state', 'age_group'], drop_first=True)

# %%
df_dummies.head()
# Out:
#    order_status  property_valuation  past_3_years_bike_related_purchases  \
# 0             1                   6                                   19
# 1             1                   6                                   19
# 2             1                   6                                   19
# 3             1                   5                                   89
# 4             1                   5                                   89
#
#    tenure profit_group  gender_Male  wealth_segment_High Net Worth  \
# 0    10.0        0-300            1                              0
# 1    10.0      300-600            1                              0
# 2    10.0        0-300            1                              0
# 3    10.0    1500-1800            0                              0
# 4    10.0      300-600            0                              0
#
#    wealth_segment_Mass Customer  owns_car_Yes  state_QLD  state_VIC  \
# ...

# %%
Y = df_dummies['order_status']
X = df_dummies.drop(['order_status'], axis=1)
model = sm.Logit(Y, sm.add_constant(X))
result = model.fit()
result.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-2fc0b0b15191> in <module>
#       1 Y = df_dummies['order_status']
#       2 X = df_dummies.drop(['order_status'], axis=1)
# ----> 3 model = sm.Logit(Y, sm.add_constant(X))
#       4 result = model.fit()
#       5 result.summary()
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, **kwargs)
#     427
#     428     def __init__(self, endog, exog, **kwargs):
# --> 429         super(BinaryModel, self).__init__(endog, exog, **kwargs)
#     430         if (not issubclass(self.__class__, MultinomialModel) and
#     431                 not np.all((self.endog >= 0) & (self.endog <= 1))):
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, **kwargs)
#     166     """
# ...

# %%
X_test = test_new
X_test.head()
# Out:
#    past_3_years_bike_related_purchases  tenure  property_valuation  \
# 0                                   86      14                   6
# 1                                   69      16                  11
# 2                                   10      10                   5
# 3                                   64       5                   1
# 4                                   34      19                   9
#
#    gender_Male  wealth_segment_High Net Worth  wealth_segment_Mass Customer  \
# 0            1                              0                             1
# 1            1                              0                             1
# 2            0                              0                             0
# 3            0                              0                             0
# 4            0                              0                             0
#
#    owns_car_Yes  state_QLD  state_VIC  age_group_30-45  age_group_45-60  \
# ...

# %%
Y_pred = result.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-5c566a13ae68> in <module>
# ----> 1 Y_pred = result.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1036
#    1037         predict_results = self.model.predict(self.params, exog, *args,
# -> 1038                                              **kwargs)
#    1039
#    1040         if exog_index is not None and not hasattr(predict_results,
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in predict(self, params, exog, linear)
#     456             exog = self.exog
#     457         if not linear:
# --> 458             return self.cdf(np.dot(exog, params))
#     459         else:
#     460             return np.dot(exog, params)
#
# ValueError: shapes (983,13) and (14,) not aligned: 13 (dim 1) != 14 (dim 0)

# %%
df_dummies.to_csv("Train.csv")

# %%
test_new.to_csv("Test.csv")
