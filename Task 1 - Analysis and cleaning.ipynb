# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import *
import os

# %%
data = pd.read_excel('KPMG_task1.xlsx', sheet_name='Transactions', index_col=None)
data=pd.DataFrame(data)
data.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
print(data.describe())
print(data.isnull().sum())
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   19803.000000             19803.000000
# mean      556.046951             38199.776549
# std       405.955660              2875.201110
# min         7.210000             33259.000000
# ...

# %%
data.shape
# Out:
# (20000, 13)

# %%
data.dtypes
# Out:
# transaction_id                      int64
# product_id                          int64
# customer_id                         int64
# transaction_date           datetime64[ns]
# online_order                      float64
# order_status                       object
# brand                              object
# product_line                       object
# product_class                      object
# product_size                       object
# list_price                        float64
# standard_cost                     float64
# product_first_sold_date           float64
# dtype: object

# %%
data['transaction_date'] = data['transaction_date'].dt.strftime('%Y/%m/%d')

# %%
data.dtypes
data.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017/02/25           0.0
# 1               2           3         3120       2017/05/21           1.0
# 2               3          37          402       2017/10/16           0.0
# 3               4          88         3135       2017/08/31           0.0
# 4               5          78          787       2017/10/01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
data[['Year','Month','Day']]=data.transaction_date.str.split('/', expand=True)
data.head()
data.dtypes
# Out:
# transaction_id               int64
# product_id                   int64
# customer_id                  int64
# transaction_date            object
# online_order               float64
# order_status                object
# brand                       object
# product_line                object
# product_class               object
# product_size                object
# list_price                 float64
# standard_cost              float64
# product_first_sold_date    float64
# Year                        object
# Month                       object
# Day                         object
# dtype: object

# %%
data[data['Year']<'2017']
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date, Year, Month, Day]
# Index: []

# %%
data[data['Month']>'12']
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date, Year, Month, Day]
# Index: []

# %%
data[data['Day']>'31']
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date, Year, Month, Day]
# Index: []

# %%
data[data['order_status']!='Approved']
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 42                 43          76          488       2017/03/17           0.0
# 138               139          32         2073       2017/03/25           0.0
# 249               250          48         1454       2017/11/25           0.0
# 254               255          67         2801       2017/04/01           1.0
# 583               584          43         1019       2017/09/13           1.0
# 752               753          22         1216       2017/05/07           0.0
# 794               795           5         2035       2017/06/05           1.0
# 857               858          81         2440       2017/03/08           1.0
# 878               879           3         2101       2017/11/09           1.0
# 892               893          66         1978       2017/12/17           0.0
# 924               925          86         1186       2017/09/14           1.0
# ...

# %%
data[data['product_id']==0]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 34                 35           0         2171       2017/08/20           0.0
# 39                 40           0         2448       2017/11/28           1.0
# 54                 55           0         3140       2017/09/18           0.0
# 60                 61           0         1839       2017/02/24           0.0
# 63                 64           0         2000       2017/07/08           0.0
# 82                 83           0         3398       2017/04/01           1.0
# 88                 89           0         2682       2017/04/04           1.0
# 99                100           0          119       2017/07/31           0.0
# 110               111           0         3320       2017/06/11           1.0
# 119               120           0          678       2017/06/16           0.0
# 136               137           0          431       2017/09/23           0.0
# ...

# %%
data[data['product_class'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 136               137           0          431       2017/09/23           0.0
# 159               160           0         3300       2017/08/27           0.0
# 366               367           0         1614       2017/03/10           0.0
# 406               407           0         2559       2017/06/14           1.0
# 676               677           0         2609       2017/07/02           0.0
# 780               781           0          897       2017/05/10           1.0
# 1003             1004           0         2254       2017/05/16           0.0
# 1130             1131           0         2163       2017/03/09           0.0
# 1196             1197           0         2234       2017/04/04           0.0
# 1282             1283           0          397       2017/08/09           0.0
# 1653             1654           0         1972       2017/10/05           0.0
# ...

# %%
print(data['online_order'].unique())
print(data['order_status'].unique())
# Out:
# [ 0.  1. nan]
# ['Approved' 'Cancelled']

# %%
df = pd.read_excel('KPMG_task1.xlsx', sheet_name='NewCustomerList', index_col=None)
df=pd.DataFrame(df)
df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
df.shape
# Out:
# (1000, 23)

# %%
df.columns.unique()
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
df.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Unnamed: 16                                   float64
# ...

# %%
df['DOB'] = df['DOB'].dt.strftime('%Y/%m/%d')

# %%
df[['Year','Month','Day']]=df.DOB.str.split('/', expand=True)
df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957/07/12             General Manager         Manufacturing
# 1  1970/03/22         Structural Engineer              Property
# 2  1974/08/28      Senior Cost Accountant    Financial Services
# 3  1979/01/28  Account Representative III         Manufacturing
# 4  1965/09/21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  Unnamed: 16  \
# 0      Mass Customer                  N      Yes  ...         0.97
# ...

# %%
df[df['Year']<'1917']
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Rank, Value, Year, Month, Day]
# Index: []
#
# [0 rows x 26 columns]

# %%
df[df['Year']=='NaT']
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases  DOB  \
# 59       Normy     Goodinge      U                                    5  NaT
# 226      Hatti     Carletti      U                                   35  NaT
# 324   Rozamond       Turtle      U                                   69  NaT
# 358      Tamas      Swatman      U                                   65  NaT
# 360      Tracy   Andrejevic      U                                   71  NaT
# 374     Agneta      McAmish      U                                   66  NaT
# 434      Gregg      Aimeric      U                                   52  NaT
# 439      Johna       Bunker      U                                   93  NaT
# 574    Harlene         Nono      U                                   69  NaT
# 598   Gerianne       Kaysor      U                                   15  NaT
# 664     Chicky      Sinclar      U                                   43  NaT
# ...

# %%
df.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure     postcode  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000  3019.227000
# std                              27.796686     5.037145   848.895767
# min                               0.000000     0.000000  2000.000000
# 25%                              26.750000     7.000000  2209.000000
# 50%                              51.000000    11.000000  2800.000000
# 75%                              72.000000    15.000000  3845.500000
# max                              99.000000    22.000000  4879.000000
#
#        property_valuation  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# count         1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean             7.397000     0.748010     0.839590     0.943498     0.870188
# std              2.758804     0.202114     0.245559     0.292143     0.275259
# ...

# %%
df.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
count=0
for i in range(len(df)):
    if df.loc[i,'Unnamed: 20']!=df.loc[i,"Rank"]:
        count+=1
print(count)

# Hence, unnamed20 = Rank. Need to drop one of the two columns
# Out:
# 0

# %%
df[df['past_3_years_bike_related_purchases']==0]
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 76      Tobias   Woodhams    Male                                    0
# 113     Meriel       Tapp  Female                                    0
# 225      Hersh   Stubbert    Male                                    0
# 322      Honey     Gosdin  Female                                    0
# 451      Katie   Warhurst  Female                                    0
# 545       Katy     Crooke  Female                                    0
# 798     Cherye  Stanfield  Female                                    0
# 904       Roth       Crum       U                                    0
# 960      Sonia   Dunstall  Female                                    0
#
#             DOB            job_title job_industry_category     wealth_segment  \
# 76   1961/04/15       Research Nurse                Health      Mass Customer
# 113  1995/08/13             VP Sales                    IT      Mass Customer
# ...

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)

# %%
df[df['gender']=='U']
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases  DOB  \
# 59       Normy     Goodinge      U                                    5  NaT
# 226      Hatti     Carletti      U                                   35  NaT
# 324   Rozamond       Turtle      U                                   69  NaT
# 358      Tamas      Swatman      U                                   65  NaT
# 360      Tracy   Andrejevic      U                                   71  NaT
# 374     Agneta      McAmish      U                                   66  NaT
# 434      Gregg      Aimeric      U                                   52  NaT
# 439      Johna       Bunker      U                                   93  NaT
# 574    Harlene         Nono      U                                   69  NaT
# 598   Gerianne       Kaysor      U                                   15  NaT
# 664     Chicky      Sinclar      U                                   43  NaT
# ...

# %%
df[df['deceased_indicator']=='Y']
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Rank, Value, Year, Month, Day]
# Index: []
#
# [0 rows x 26 columns]

# %%
df['job_industry_category'].unique()
# Out:
# array(['Manufacturing', 'Property', 'Financial Services', 'Entertainment',
#        'Retail', 'IT', 'Telecommunications', 'Health', nan, 'Argiculture'],
#       dtype=object)

# %%
df['wealth_segment'].unique()
# Out:
# array(['Mass Customer', 'Affluent Customer', 'High Net Worth'],
#       dtype=object)

# %%
df['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
count=0
df['postcode']=df['postcode'].astype(int).astype(str)
for i in df['postcode']:
    if len(i)>4:
        count=count+1
print(count)
# Out:
# 0

# %%
df['country'].unique()
# Out:
# array(['Australia'], dtype=object)

# %%
df['state'].unique()
# Out:
# array(['QLD', 'NSW', 'VIC'], dtype=object)

# %%
df_1 = pd.read_excel('KPMG_task1.xlsx', sheet_name='CustomerDemographic', index_col=None)
df_1=pd.DataFrame(df_1)
df_1.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
def details(table):
    print(table.describe())
    print(table.isnull().sum())
    print(table.columns.unique())
    print(table.head())

details(df_1)
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# ...

# %%
df_1.shape
# Out:
# (4000, 13)

# %%
df_1.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
df_1.sort_values('Year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-5be8e8625191> in <module>
# ----> 1 df_1.sort_values('Year')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'Year'

# %%
df_2 = df_1[df_1['Year']!='NaT']
df_2.sort_values('Day', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-9129b3d230bd> in <module>
# ----> 1 df_2 = df_1[df_1['Year']!='NaT']
# ...

# %%
days_31 = df_2[df_2['Day']=='31']
days_31
# Out:
#       customer_id  first_name    last_name  gender  \
# 95             96       Heath       Olford    Male
# 109           110      Sascha  St. Quintin    Male
# 148           149       Drucy      Kausche  Female
# 150           151      Donnie      Brimson    Male
# 207           208      Rutter       Excell    Male
# 339           340     Joshuah       Purvey    Male
# 407           408      Kurtis      Baistow    Male
# 410           411   Cathyleen         Bern  Female
# 414           415    Conchita        Jeans  Female
# 488           489       Tresa        Reeks  Female
# 568           569       Jaime       Warkup    Male
# 677           678       Ambur      Symcoxe  Female
# 702           703     Ethelda          NaN  Female
# 750           751        Amie        Dufty  Female
# 764           765     Valeria     Chazette  Female
# 799           800       Quint        Popov    Male
# 829           830      Jayson     Chilcott    Male
# ...

# %%
days_31['Month'].unique()
# Out:
# array(['08', '07', '01', '10', '03', '05', '12'], dtype=object)

# %%
feb=df_1[df_1['Month']=='02']
feb['Day'].unique()
# Out:
# array(['23', '15', '27', '10', '26', '08', '04', '13', '07', '03', '24',
#        '05', '22', '28', '19', '09', '16', '17', '12', '20', '21', '14',
#        '18', '06', '01', '11', '02', '25', '29'], dtype=object)

# %%
feb_leap=feb[feb['Day']=='29']
feb_leap['Year'].unique()
# Out:
# array(['1980', '1964'], dtype=object)

# %%
df_1['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
df_1[df_1['deceased_indicator']=='Y']
# Out:
#       customer_id first_name    last_name  gender  \
# 752           753       Josy  St. Quentin  Female
# 3789         3790     Kurtis       Morson    Male
#
#       past_3_years_bike_related_purchases         DOB      job_title  \
# 752                                    82  1970/03/07   Food Chemist
# 3789                                   91  1959/05/31  Senior Editor
#
#      job_industry_category     wealth_segment deceased_indicator  \
# 752                 Health  Affluent Customer                  Y
# 3789                Retail      Mass Customer                  Y
#
#                                                 default owns_car  tenure  \
# 752                                                -0.5      Yes     6.0
# 3789  ÌÌºÍÌ¹Ì¯ÍTÌ±Ì¤ÍÌ¥ÍÍhÍÌ²eÍÍÌ¼ÌÌÌ¼Ì£Í ÍÌÌ±Ì ÍÍÍN...      Yes     9.0
#
#       Year Month Day
# 752   1970    03  07
# 3789  1959    05  31

# %%
df_1['deceased_indicator'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df_1['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_1['wealth_segment'].unique()
# Out:
# array(['Mass Customer', 'Affluent Customer', 'High Net Worth'],
#       dtype=object)

# %%
df_2.sort_values('Year')
# Out:
#       customer_id  first_name        last_name  gender  \
# 33             34    Jephthah         Bachmann       U
# 719           720      Darrel            Canet    Male
# 1091         1092      Katlin          Creddon  Female
# 3409         3410     Merrili          Brittin  Female
# 2412         2413       Abbey           Murrow    Male
# 657           658        Donn          Bonnell    Male
# 0               1     Laraine        Medendorp       F
# 424           425  Michaeline          Bordman  Female
# 2745         2746    Carmelia  Egle of Germany  Female
# 2812         2813     Lillian         Crookall  Female
# 2958         2959         Max         Gonthier  Female
# 1564         1565         Jay      Janiszewski    Male
# 3258         3259        Rabi              NaN    Male
# 3470         3471       Brita           Afonso  Female
# 1242         1243     Robbert           Blakey    Male
# 1176         1177    Bobbette            Pozzi  Female
# ...

# %%
under_18 = df_1[df_1['Year']>'1997']
len(under_18)
# Out:
# 309

# %%
under_18['job_title'].unique()
# Out:
# array(['Junior Executive', 'Geological Engineer',
#        'Physical Therapy Assistant', 'Account Executive', 'VP Accounting',
#        'Recruiting Manager', nan, 'Assistant Professor',
#        'Environmental Tech', 'Senior Editor', 'General Manager',
#        'Desktop Support Technician', 'Associate Professor',
#        'Senior Sales Associate', 'Financial Advisor', 'Pharmacist',
#        'Software Engineer IV', 'Structural Analysis Engineer',
#        'Staff Scientist', 'Sales Representative',
#        'GIS Technical Architect', 'Help Desk Technician',
#        'Quality Control Specialist', 'Research Nurse', 'Internal Auditor',
#        'Registered Nurse', 'Tax Accountant', 'Social Worker',
#        'Chemical Engineer', 'Chief Design Engineer',
#        'Senior Financial Analyst', 'Help Desk Operator',
#        'Computer Systems Analyst II', 'Administrative Officer',
#        'Senior Developer', 'Business Systems Development Analyst',
# ...

# %%
under_18.sort_values('tenure', ascending=False)
# Out:
#       customer_id  first_name   last_name  gender  \
# 1679         1680       Loise     Austins  Female
# 585           586       Jayme     Baunton  Female
# 1735         1736      Garrek   Rowbotham    Male
# 2223         2224       Sydel    Seccombe  Female
# 1723         1724      Davita    Pristnor  Female
# 1713         1714        Esma     Rycroft  Female
# 1962         1963       Syman    Trimnell    Male
# 1533         1534   Rosabelle  Hollington  Female
# 1970         1971      Mariel        Dyke  Female
# 2740         2741    Reinwald     Sinkins    Male
# 2188         2189     Thedric         NaN    Male
# 2301         2302     Loraine     Beamish  Female
# 703           704     Lindsay     Acaster  Female
# 1333         1334      Cicily       Jenks  Female
# 2625         2626      Gerome     Lawrenz    Male
# 771           772    Lorianna    Vidyapin  Female
# 1458         1459      Haydon     Berkery    Male
# 3356         3357     Georgie       Henze    Male
# ...

# %%
under_18['tenure'].max()
# Out:
# 4.0

# %%
under_18['Year'].unique()
# Out:
# array(['2000', '2001', '2002', '1998', '1999', 'NaT'], dtype=object)

# %%
data1 = pd.read_excel('KPMG_task1.xlsx', sheet_name='CustomerAddress', index_col=None)
data1=pd.DataFrame(data1)
data1.head()

def details(table):
    print(table.describe())
    print(table.isnull().sum())
    print(table.columns.unique())
    print(table.head())

# %%
details(data1)
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# ...

# %%
data1.shape
# Out:
# (3999, 6)

# %%
data1['state'].unique()
# Out:
# array(['New South Wales', 'QLD', 'VIC', 'NSW', 'Victoria'], dtype=object)

# %%
for i in (df_1['customer_id']):
    if i not in data1['customer_id']:
        print(i)
# Out:
# 3999
# 4000

# %%
df_1.sort_values('customer_id', ascending=False)
# Out:
#       customer_id      first_name      last_name  gender  \
# 3999         4000           Kippy        Oldland    Male
# 3998         3999       Patrizius            NaN    Male
# 3997         3998          Sarene        Woolley       U
# 3996         3997          Blanch         Nisuis  Female
# 3995         3996         Rosalia       Halgarth  Female
# 3994         3995           Rusty         Iapico    Male
# 3993         3994         Stephie          Byars  Female
# 3992         3993            Andi        Dumelow  Female
# 3991         3992         Germain        Tireman    Male
# 3990         3991           Rolph       Sweetnam    Male
# 3989         3990         Reynard         Hagger    Male
# 3988         3989         Nicolas        Burdass    Male
# 3987         3988       Ammamaria       Ashburne  Female
# 3986         3987          Beckie        Wakeham  Female
# 3985         3986          Oralle       Petrello  Female
# ...

# %%
data1.sort_values('customer_id', ascending=False)
# Out:
#       customer_id                     address  postcode            state  \
# 3998         4003             320 Acker Drive      2251              NSW
# 3997         4002            8194 Lien Street      4032              QLD
# 3996         4001      87 Crescent Oaks Alley      2756              NSW
# 3995         4000   57042 Village Green Point      4511              QLD
# 3994         3999             1482 Hauk Trail      3064              VIC
# 3993         3998        736 Roxbury Junction      2540              NSW
# 3992         3997         4 Dovetail Crossing      2350              NSW
# 3991         3996          0 Transport Center      3977              VIC
# 3990         3995               613 Erie Lane      2088              NSW
# 3989         3994      2918 Summer Ridge Hill      3030              VIC
# 3988         3993           681 Elmside Place      3750              VIC
# 3987         3992             8 Randy Parkway      2209              NSW
# ...

# %%
data1['country'].unique()
# Out:
# array(['Australia'], dtype=object)
